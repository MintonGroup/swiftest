# %%
import numpy as np
import swiftest
import matplotlib.pyplot as plt

# %%
swiftersim = swiftest.Simulation(param_file="param.swifter.in", codename="Swifter")
swiftersim.bin2xr()
# Out:
# Reading Swifter file param.swifter.in
# Reading in time 4.200e+03
# Creating Dataset
# Successfully converted 8 output frames.
# Swifter simulation data stored as xarray DataSet .ds

# %%
swiftestsim = swiftest.Simulation(param_file="param.swiftest.in")
swiftestsim.bin2xr()
# Out:
# Reading Swiftest file param.swiftest.in
# Reading in time 4.200e+03
# Creating Dataset
# Successfully converted 8 output frames.
#
# Adding particle info to Dataset
# Swiftest simulation data stored as xarray DataSet .ds

# %%
swiftdiff = (swiftestsim.ds - swiftersim.ds) / swiftersim.ds

# %%
fig, ax = plt.subplots()
swiftdiff['vx'].plot.line(ax=ax, x="time")
legend = ax.legend()
legend.remove()
plt.show()
print("")
# Out:
# No handles with labels found to put in legend.

# %%
swiftdiff.isel(time=5)['vx']
# Out:
# <xarray.DataArray 'vx' (id: 1500)>
# array([-0.,  0., -0., ...,  0., -0., -0.])
# Coordinates:
#   * id       (id) float64 2.0 3.0 4.0 5.0 ... 1.499e+03 1.5e+03 1.501e+03
#     time     float64 3e+03
