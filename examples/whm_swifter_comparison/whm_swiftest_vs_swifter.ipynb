# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import swiftestio as swio
from astroquery.jplhorizons import Horizons

# %%
inparfile = 'param.swifter.in'
param = swio.read_swifter_param(inparfile)
swifterdat = swio.swifter2xr(param)
# Out:
# Reading Swifter file param.swifter.in

# %%
param_file_name = 'param.swiftest.in'
config = swio.read_swiftest_config(param_file_name)
swiftestdat = swio.swiftest2xr(config)
# Out:
# Reading Swiftest file param.swiftest.in

# %%
swiftdiff = swiftestdat - swifterdat

# %%
swiftdiff = swiftdiff.rename({'time' : 'time (y)'})

# %%
swiftdiff['dr'] = np.sqrt(swiftdiff['px']**2 + swiftdiff['py']**2 + swiftdiff['pz']**2)
swiftdiff['dv'] = np.sqrt(swiftdiff['vx']**2 + swiftdiff['vy']**2 + swiftdiff['vz']**2)

# %%
swiftdiff['dr'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc8c88f07c0>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977580>,
#  <matplotlib.lines.Line2D at 0x7fc8f89777f0>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977a00>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977e50>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977eb0>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977640>,
#  <matplotlib.lines.Line2D at 0x7fc8f89771c0>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977190>,
#  <matplotlib.lines.Line2D at 0x7fc8f8977130>,
#  <matplotlib.lines.Line2D at 0x7fc8f8953040>,
#  <matplotlib.lines.Line2D at 0x7fc8f8970610>,
#  <matplotlib.lines.Line2D at 0x7fc8f8970df0>]

# %%
swiftdiff['dv'].sel(id=2).plot.line(x="time (y)")

# %%
swiftdiff['pz'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc8c88f0c40>,
#  <matplotlib.lines.Line2D at 0x7fc8d9842ca0>,
#  <matplotlib.lines.Line2D at 0x7fc8d9842880>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d1dc0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d18e0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d16d0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d1160>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d1f10>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d1c70>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d1f70>,
#  <matplotlib.lines.Line2D at 0x7fc8c8764130>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d10a0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d1220>]

# %%
swiftdiff['vx'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc900950040>,
#  <matplotlib.lines.Line2D at 0x7fc900950160>,
#  <matplotlib.lines.Line2D at 0x7fc900950c40>,
#  <matplotlib.lines.Line2D at 0x7fc9009509d0>,
#  <matplotlib.lines.Line2D at 0x7fc900950f10>,
#  <matplotlib.lines.Line2D at 0x7fc9009505e0>,
#  <matplotlib.lines.Line2D at 0x7fc900950b50>,
#  <matplotlib.lines.Line2D at 0x7fc900950dc0>,
#  <matplotlib.lines.Line2D at 0x7fc9009509a0>,
#  <matplotlib.lines.Line2D at 0x7fc900950700>,
#  <matplotlib.lines.Line2D at 0x7fc8e88e5ee0>,
#  <matplotlib.lines.Line2D at 0x7fc900950be0>,
#  <matplotlib.lines.Line2D at 0x7fc900950fd0>]

# %%
swiftdiff['vy'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc8d951e580>,
#  <matplotlib.lines.Line2D at 0x7fc8d951e460>,
#  <matplotlib.lines.Line2D at 0x7fc8d953a5b0>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550dc0>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550f40>,
#  <matplotlib.lines.Line2D at 0x7fc8d95508e0>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550880>,
#  <matplotlib.lines.Line2D at 0x7fc8d95509d0>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550b20>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550b50>,
#  <matplotlib.lines.Line2D at 0x7fc8d953a8e0>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550700>,
#  <matplotlib.lines.Line2D at 0x7fc8d9550790>]

# %%
swiftdiff['vz'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc8f89d5ee0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5df0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5d90>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d52b0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5160>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d51c0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5040>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5c40>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5610>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d56a0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89b3130>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5ac0>,
#  <matplotlib.lines.Line2D at 0x7fc8f89d5970>]
