# %%
import swiftest
import os
import xarray as xr
import numpy as np
os.getcwd()
# Out:
# '/home/daminton/git/swiftest/examples/symba_mars_disk'

# %%
sim = swiftest.Simulation(param_file="param.in")
sim.bin2xr()
# Out:
# Reading Swiftest file param.in
#
# Creating Dataset
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-6fa7d06e00e8> in <module>
#       1 sim = swiftest.Simulation(param_file="param.in")
# ----> 2 sim.bin2xr()
#
# ~/git/swiftest/python/swiftest/swiftest/simulation_class.py in bin2xr(self)
#     172     def bin2xr(self):
#     173         if self.codename == "Swiftest":
# --> 174             self.ds = io.swiftest2xr(self.param)
#     175             print('Swiftest simulation data stored as xarray DataSet .ds')
#     176         elif self.codename == "Swifter":
#
# ~/git/swiftest/python/swiftest/swiftest/io.py in swiftest2xr(param)
#     697         print('\nCreating Dataset')
#     698         ds = xr.open_dataset(param['BIN_OUT'])
# --> 699         ds = clean_string_values(param, ds)
#     700     else:
# ...

# %%
ds = xr.open_dataset('bin.nc')

# %%
ds['name'].isel(id=-200)
# Out:
# <xarray.DataArray 'name' ()>
# array(b'UNNAMED', dtype='|S32')
# Coordinates:
#     id       int32 1885
