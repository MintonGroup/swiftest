# %%
# %load_ext autoreload
# %autoreload 2
import swiftest
import os
import xarray as xr
import numpy as np
from netCDF4 import Dataset
os.getcwd()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '/home/daminton/gittmp/swiftest/examples/symba_mars_disk'

# %%
sim = swiftest.Simulation(param_file="param.in")
sim.bin2xr()
# Out:
# Reading Swiftest file param.in
#
# Creating Dataset from NetCDF file
# Successfully converted 11 output frames.
# Swiftest simulation data stored as xarray DataSet .ds

# %%
sim.ds.id
# Out:
# <xarray.DataArray 'id' (id: 1525)>
# array([   0,    1,    2, ..., 1522, 1523, 1524], dtype=int32)
# Coordinates:
#   * id       (id) int32 0 1 2 3 4 5 6 7 ... 1518 1519 1520 1521 1522 1523 1524
# Attributes:
#     _FillValue:  -2147483647

# %%
sim.ds.id
# Out:
# <xarray.DataArray 'id' (id: 1525)>
# array([0.000e+00, 1.000e+00, 2.000e+00, ..., 1.522e+03, 1.523e+03, 1.524e+03])
# Coordinates:
#   * id       (id) float64 0.0 1.0 2.0 3.0 ... 1.522e+03 1.523e+03 1.524e+03

# %%
osd['id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c607f1abec00> in <module>
# ----> 1 osd['id']
#
# NameError: name 'osd' is not defined

# %%
ds = xr.open_dataset(sim.param['BIN_OUT'], mask_and_scale=False)
ds = swiftest.io.clean_string_values(sim.param, ds)

# %%
ods = xr.open_dataset('bin.nc', mask_and_scale=False)

# %%
ods['a']

# %%
ods.id

# %%
sim.ds.sel(id=1501)['a']

# %%
cds.sel(id=1501)['a']
