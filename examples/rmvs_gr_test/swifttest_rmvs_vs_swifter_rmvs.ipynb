# %%
import numpy as np
import swiftestio as swio
import matplotlib.pyplot as plt

# %%
inparfile = 'param.swifter.in'
paramgr = swio.read_swifter_param(inparfile)
swifterdat = swio.swifter2xr(paramgr)
# Out:
# Reading Swifter file param.swifter.in

# %%
config_file_name = 'config.swiftest.in'
config = swio.read_swiftest_config(config_file_name)
swiftestdat = swio.swiftest2xr(config)
# Out:
# Reading Swiftest file config.swiftest.in

# %%
swiftdiff = swiftestdat - swifterdat

# %%
swiftdiff = swiftdiff.rename({'time' : 'time (y)'})

# %%
swiftdiff['a'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7ff0608c8f40>,
#  <matplotlib.lines.Line2D at 0x7ff0608c8520>,
#  <matplotlib.lines.Line2D at 0x7ff0608c8df0>,
#  <matplotlib.lines.Line2D at 0x7ff0608c81f0>,
#  <matplotlib.lines.Line2D at 0x7ff0608c8220>,
#  <matplotlib.lines.Line2D at 0x7ff0608c8160>,
#  <matplotlib.lines.Line2D at 0x7ff0608c8280>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7220>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7640>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7e80>,
#  <matplotlib.lines.Line2D at 0x7ff021368eb0>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7400>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7bb0>,
#  <matplotlib.lines.Line2D at 0x7ff0608c79d0>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7f40>,
#  <matplotlib.lines.Line2D at 0x7ff0608c76a0>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7940>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7190>,
#  <matplotlib.lines.Line2D at 0x7ff0608c7ca0>]
