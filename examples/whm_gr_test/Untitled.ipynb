# %%
import swiftest
import numpy as np

# %%
sim = swiftest.Simulation(param_file="param.swiftest.in")
# Out:
# Reading Swiftest file param.swiftest.in

# %%
sim.bin2xr()
# Out:
# Creating Dataset
# Successfully converted 3 output frames.
# Swiftest simulation data stored as xarray DataSet .ds

# %%
sim.ds.sel(id=1)['name']
# Out:
# <xarray.DataArray 'name' (str: 32)>
# array([b'M', b'e', b'r', b'c', b'u', b'r', b'y', b'', b'', b'', b'', b'', b'',
#        b'', b'', b'', b'', b'', b'', b'', b'', b'', b'', b'', b'', b'', b'',
#        b'', b'', b'', b'', b''], dtype='|S1')
# Coordinates:
#     id       int32 1
# Dimensions without coordinates: str

# %%
ds = sim.ds

# %%
for i in ds.id:
    ds['name'].sel(id=i) = 'test'
# Out:
#   File "<ipython-input-15-f84d24081226>", line 2
#     ds['name'].sel(id=i) = 'test'
#     ^
# SyntaxError: can't assign to function call

# %%
dsclean
# Out:
# array('SMVEMJSUNueeaauarenrnrrptap\x00cutsiunt\x00ush\x00truu\x00r\x00\x00\x00ensn\x00y\x00\x00\x00r\x00\x00e',
#       dtype='<U288')
