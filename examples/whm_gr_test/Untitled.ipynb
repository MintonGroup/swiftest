# %%
import swiftest
import numpy as np
import xarray as xr

# %%
sim = swiftest.Simulation(param_file="param.swiftest.in")
# Out:
# Reading Swiftest file param.swiftest.in

# %%
sim.bin2xr()
# Out:
# Creating Dataset
# Successfully converted 3 output frames.
# Swiftest simulation data stored as xarray DataSet .ds

# %%
ds = sim.ds

# %%
ds['name']
# Out:
# <xarray.DataArray 'name' (id: 9)>
# array(['Sun', 'Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn',
#        'Uranus', 'Neptune'], dtype='<U7')
# Coordinates:
#   * id       (id) int32 0 1 2 3 4 5 6 7 8

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (id: 9, time: 3)
# Coordinates:
#   * time           (time) float64 0.0 0.0006845 0.001369
#   * id             (id) int32 0 1 2 3 4 5 6 7 8
# Data variables: (12/19)
#     npl            (time) int32 ...
#     ntp            (time) int32 ...
#     name           (id) <U7 'Sun' 'Mercury' 'Venus' ... 'Uranus' 'Neptune'
#     particle_type  (id) <U12 'Central Body' 'Massive Body' ... 'Massive Body'
#     xhx            (time, id) float64 ...
#     xhy            (time, id) float64 ...
#     ...             ...
#     capom          (time, id) float64 ...
#     omega          (time, id) float64 ...
#     capm           (time, id) float64 ...
#     Gmass          (time, id) float64 ...
#     rhill          (time, id) float64 ...
#     radius         (time, id) float64 ...
