# %%
import numpy as np
import swiftestio as swio
import matplotlib.pyplot as plt

# %%
inparfile = 'param.swifter.in'
paramgr = swio.read_swifter_param(inparfile)
swifterdat = swio.swifter2xr(paramgr)
# Out:
# Reading Swifter file param.swifter.in

# %%
config_file_name = 'config.swiftest.in'
config = swio.read_swiftest_config(config_file_name)
swiftestdat = swio.swiftest2xr(config)
# Out:
# Reading Swiftest file config.swiftest.in

# %%
swiftdiff = swiftestdat - swifterdat

# %%
swiftdiff = swiftdiff.rename({'time' : 'time (y)'})

# %%
swiftdiff['px'].plot.line(x="time (y)")
# Out:
# [<matplotlib.lines.Line2D at 0x7fc738cccfa0>,
#  <matplotlib.lines.Line2D at 0x7fc7405068e0>,
#  <matplotlib.lines.Line2D at 0x7fc740506a90>,
#  <matplotlib.lines.Line2D at 0x7fc740506c40>,
#  <matplotlib.lines.Line2D at 0x7fc740506c70>,
#  <matplotlib.lines.Line2D at 0x7fc740506d30>,
#  <matplotlib.lines.Line2D at 0x7fc740506df0>,
#  <matplotlib.lines.Line2D at 0x7fc740506eb0>,
#  <matplotlib.lines.Line2D at 0x7fc740506f70>,
#  <matplotlib.lines.Line2D at 0x7fc740512070>,
#  <matplotlib.lines.Line2D at 0x7fc7404e5be0>,
#  <matplotlib.lines.Line2D at 0x7fc7405121c0>,
#  <matplotlib.lines.Line2D at 0x7fc740512280>,
#  <matplotlib.lines.Line2D at 0x7fc740512340>,
#  <matplotlib.lines.Line2D at 0x7fc740512400>,
#  <matplotlib.lines.Line2D at 0x7fc7405124c0>,
#  <matplotlib.lines.Line2D at 0x7fc740512580>,
#  <matplotlib.lines.Line2D at 0x7fc740512640>,
#  <matplotlib.lines.Line2D at 0x7fc740512700>]
