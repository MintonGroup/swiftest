# %%
import numpy as np
import swiftestio as swio
import matplotlib.pyplot as plt

# %%
inparfile = 'param.swifter.in'
paramgr = swio.read_swifter_param(inparfile)
swifterdat = swio.swifter2xr(paramgr)
# Out:
# Reading Swifter file param.swifter.in

# %%
swifterdat.plot.scatter(x='px', y='py', hue='id', hue_style="discrete", marker='.')
# Out:
# [<matplotlib.collections.PathCollection at 0x7f8228b8daf0>,
#  <matplotlib.collections.PathCollection at 0x7f81f9a58c40>]

# %%
config_file_name = 'config.swiftest.in'
config = swio.read_swiftest_config(config_file_name)
swiftestdat = swio.swiftest2xr(config)
# Out:
# Reading Swiftest file config.swiftest.in

# %%
swiftestdat.plot.scatter(x='px', y='py', hue='id', hue_style="discrete", marker='.')
# Out:
# [<matplotlib.collections.PathCollection at 0x7f8200ac8df0>,
#  <matplotlib.collections.PathCollection at 0x7f8200ac8310>,
#  <matplotlib.collections.PathCollection at 0x7f8200ac81c0>]

# %%
swiftdiff = swiftestdat - swifterdat

# %%
swiftdiff.plot.scatter(x='px', y='py', hue='id', hue_style="discrete", marker='.')
# Out:
# [<matplotlib.collections.PathCollection at 0x7f81f9b3e250>,
#  <matplotlib.collections.PathCollection at 0x7f81f9b3e7c0>]
